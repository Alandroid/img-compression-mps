# %%
import sys
import os
from pathlib import Path

# Automatically find the project root (assumes "src" is in the project)
current_file = Path(__file__).resolve() if '__file__' in locals() else Path.cwd()
project_root = current_file
while not (project_root / "src").exists() and project_root != project_root.parent:
    project_root = project_root.parent

# Ensure we found the correct project root
if not (project_root / "src").exists():
    raise FileNotFoundError("Could not find project root containing 'src' directory.")

# Set the working directory to the project root
os.chdir(project_root)
from src.compression.mps_ND import NDMPS
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from src.compression.utils_ND import *
import pickle as pkl
from copy import deepcopy
# Out:
# /Users/maxge/miniconda3/envs/QEL/lib/python3.10/site-packages/cotengra/hyperoptimizers/hyper.py:33: UserWarning: Couldn't import `kahypar` - skipping from default hyper optimizer and using basic `labels` method instead.
#   warnings.warn(

# %%
mri_file = 'Data/ds003799-2.0.0/sub-season127_ses-2_acq-MPrageHiRes_T1w.nii.gz'
img = nib.load(mri_file)
img_data = img.get_fdata()
print(type(img_data))  # it's a numpy array!
print(img_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (224, 256, 256)

# %%
mid_slice_x = img_data[128, :, :]
print(mid_slice_x.shape)
# Note that the transpose the slice (using the .T attribute).
# This is because imshow plots the first dimension on the y-axis and the
# second on the x-axis, but we'd like to plot the first on the x-axis and the
# second on the y-axis. Also, the origin to "lower", as the data was saved in
# "cartesian" coordinates.
plt.imshow(mid_slice_x.T, cmap='gray', origin='lower')
#plt.colorbar(label='Signal intensity')
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# (256, 256)

# %%
mps = NDMPS.from_tensor(mid_slice_x, norm = False, mode="Std")

# %%
mps.compression_ratio()
# Out:
# np.float64(1.877685546875)

# %%
mps.continuous_compress(0.137)
# Out:
# Compression ratio at 0.0: 1.877685546875
# Compression ratio at 0.007210526315789474: 1.8095703125
# Compression ratio at 0.014421052631578947: 1.70361328125
# Compression ratio at 0.021631578947368422: 1.55224609375
# Compression ratio at 0.028842105263157895: 1.3896484375
# Compression ratio at 0.03605263157894737: 1.2518310546875
# Compression ratio at 0.043263157894736844: 1.1475830078125
# Compression ratio at 0.050473684210526316: 1.03369140625
# Compression ratio at 0.05768421052631579: 0.9366455078125
# Compression ratio at 0.06489473684210527: 0.84283447265625
# Compression ratio at 0.07210526315789474: 0.74676513671875
# Compression ratio at 0.07931578947368421: 0.65576171875
# Compression ratio at 0.08652631578947369: 0.57940673828125
# Compression ratio at 0.09373684210526315: 0.515869140625
# Compression ratio at 0.10094736842105263: 0.47119140625
# Compression ratio at 0.10815789473684212: 0.41400146484375
# Compression ratio at 0.11536842105263158: 0.35943603515625
# Compression ratio at 0.12257894736842105: 0.30242919921875
# Compression ratio at 0.12978947368421054: 0.24456787109375
# Compression ratio at 0.137: 0.20465087890625

# %%
mps.compression_ratio()
# Out:
# np.float64(0.20465087890625)

# %%
mps.compression_ratio_on_disk()
# Out:
# np.float64(0.1948394775390625)

# %%
recovered_img = mps.to_tensor()

# %% [markdown]
# y: 10:220
# z: :175
# x: 40:200

# %%
plt.imshow(recovered_img.T, cmap='gray', origin='lower')
#plt.xlabel('First axis')
#plt.ylabel('Second axis')
#plt.colorbar(label='Signal intensity')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
calc_PSNR(mid_slice_x, recovered_img)
# Out:
# np.float64(26.181110938958298)

# %%
compute_ssim_2D(mid_slice_x, recovered_img)
# Out:
# np.float64(0.7628496089894539)

# %%
avg_SSIM_3D(img_data, recovered_img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 avg_SSIM_3D(mid_slice_x, recovered_img)
#
# File ~/Documents/01_Studium/04_München/02_SS 2024/QEL/Block encoding generalization/img-compression-mps/src/compression/utils_ND.py:139, in avg_SSIM_3D(original, compressed)
#     135 def avg_SSIM_3D(original, compressed):
#     136     """
#     137     Compute the average SSIM of a 3D image along all axes.
#     138     """
# --> 139     ssim_0 = SSIM_3D_axis(original, compressed, axis = 0)
#     140     ssim_1 = SSIM_3D_axis(original, compressed, axis = 1)
#     141     ssim_2 = SSIM_3D_axis(original, compressed, axis = 2)
#
# File ~/Documents/01_Studium/04_München/02_SS 2024/QEL/Block encoding generalization/img-compression-mps/src/compression/utils_ND.py:124, in SSIM_3D_axis(original, compressed, axis)
#     122 if axis == 0:
#     123     for i in np.arange(original.shape[0]):
# --> 124         ssim_list.append(compute_ssim_2D(original[i, :, :], compressed[i, :, :]))
#     126 elif axis == 1:
#     127     for i in np.arange(original.shape[1]):
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
from src.evaluation.benchmark import load_tensors

# %%
ped = load_tensors(["Data/pedestrians/seq_00000.npz"], ".npz", shape = (200,144,216))
ped_tensor = ped[0][0]
ped_tensor.shape
# Out:
# Loading file 1/1
# (200, 144, 216)

# %%
plt.imshow(ped_tensor[100, :, :].T, cmap='gray', origin='lower')

# %%
mps_ped = NDMPS.from_tensor(ped_tensor, norm = False, mode="Std")
# Out:
# /Users/maxge/Documents/01_Studium/04_München/02_SS 2024/QEL/Block encoding generalization/img-compression-mps/src/compression/utils_ND.py:82: RuntimeWarning: invalid value encountered in cast
#   prod_block_sizes[0] = prod_block_sizes [0] * 1e100

# %%
mps_ped.compression_ratio()
# Out:
# np.float64(1.2451131687242798)

# %%
mps_ped.compress_to_dtype(np.uint8, replace=True)
# Out:
# [array([[ 97, 150, 130, 113, 135, 116, 122, 187, 125, 213,  81, 123, 128,
#          126, 127,   1],
#         [ 99, 124,  92,  90, 148, 230, 151, 113, 124, 130, 119, 123, 126,
#            2, 127, 126],
#         [ 97, 113, 207, 178,  77, 163, 158, 123, 122, 130, 116, 125, 120,
#          126, 250, 126],
#         [ 69,  75,  84, 198, 150, 127, 100, 138, 253, 133, 146, 130, 123,
#          126, 126, 126],
#         [101,  87, 185,  88, 159, 137,  84, 168, 118, 105, 169, 122, 255,
#          125, 125, 126],
#         [ 63, 176,  99,  92,  75,  87, 213, 135, 139, 137, 226, 137, 142,
#          125, 126, 126],
#         [ 79,  59, 128,  60, 118,  76, 187, 145, 145,  58,  37, 126, 116,
#          126, 126, 126],
#         [ 72, 188, 157, 141, 201, 112, 121,  91, 118, 100, 106, 246, 121,
#          126, 127, 126],
#         [ 96, 150, 130, 113, 135, 116, 122, 188, 125, 214,  81, 123, 128,
#          126, 126, 249],
#         [ 98, 124,  93,  90, 148, 229, 152, 112, 124, 130, 120, 122, 127,
#          250, 126, 126],
#         [ 96, 113, 207, 178,  78, 163, 159, 123, 122, 131, 116, 126, 119,
#          125,   2, 126],
#         [ 70,  82,  59, 203, 140, 115, 129, 163,  12, 107, 135, 122, 127,
#          126, 126, 126],
#         [103, 101, 174,  79, 153, 137,  84, 188, 116, 107, 193, 124,  10,
#          126, 126, 126],
#         [ 65, 172,  99, 104,  25, 141,  22, 123, 126,  87,  98, 132, 129,
#          126, 126, 126],
#         [ 80,  52, 136,  88, 121,  94,  95,  15,  99, 205, 142, 129, 116,
#          125, 126, 126],
#         [ 70, 190, 152, 139, 186, 104, 123,  86, 126,  99, 115,   0, 120,
#          125, 126, 126]], dtype=uint8),
#  array([[[ 98, 129, 114, ..., 125, 126, 123],
#          [ 95, 121, 126, ..., 125, 125, 138],
#          [ 96, 136, 130, ..., 106, 125, 125],
#          ...,
#          [ 91, 120, 134, ..., 126, 113, 126],
#          [ 91, 126, 133, ..., 126, 126, 125],
#          [ 90, 131, 117, ..., 128, 127, 126]],
#
#         [[136, 127, 133, ..., 124, 125, 124],
#          [131, 100, 129, ..., 126, 125, 139],
#          [121, 114, 134, ..., 119, 125, 126],
#          ...,
#          [129, 107, 128, ..., 125, 112, 123],
#          [121, 106, 137, ..., 124, 125, 124],
#          [114, 123, 114, ..., 122, 124, 124]],
#
#         [[128, 125, 115, ..., 126, 124, 125],
#          [126, 104, 130, ..., 125, 125,  97],
#          [124, 145, 138, ..., 173, 125, 125],
#          ...,
#          [122, 118, 137, ..., 124, 151, 124],
#          [122, 126, 145, ..., 125, 126, 123],
#          [132, 143, 168, ..., 126, 126, 124]],
#
#         ...,
#
#         [[125, 125, 125, ..., 126, 126, 126],
#          [125, 125, 125, ..., 125, 125, 125],
#          [125, 125, 125, ..., 125, 125, 125],
#          ...,
#          [125, 125, 125, ..., 119, 127, 122],
#          [125, 125, 129, ..., 125, 125, 125],
#          [125, 126, 125, ..., 125, 125, 125]],
#
#         [[125, 125, 125, ..., 125, 126, 127],
#          [125, 125, 125, ..., 126, 125, 126],
#          [125, 125, 125, ...,  37, 114, 125],
#          ...,
#          [125, 125, 125, ..., 127, 125, 123],
#          [125, 125, 125, ..., 126, 124, 125],
#          [125, 126, 125, ..., 125, 125, 125]],
#
#         [[125, 125, 125, ..., 124, 125, 125],
#          [125, 125, 125, ..., 124, 124, 126],
#          [125, 125, 125, ..., 123, 124, 125],
#          ...,
#          [125, 125, 125, ..., 126, 125, 126],
#          [125, 125, 125, ..., 123, 125, 124],
#          [125, 125, 125, ..., 123, 122, 125]]], dtype=uint8),
#  array([[[  9, 161, 178, ..., 139, 158, 162],
#          [  8, 143, 181, ..., 148, 165, 156],
#          [  8, 150, 184, ..., 156, 169, 157],
#          ...,
#          [  5, 181, 142, ..., 170, 159, 141],
#          [  0, 155, 147, ..., 149, 146, 142],
#          [  0, 144, 134, ..., 155, 150, 150]],
#
#         [[180, 202, 190, ..., 136, 174, 187],
#          [159, 214, 181, ..., 153, 136, 164],
#          [138, 176, 178, ..., 152, 160, 144],
#          ...,
#          [175, 197, 168, ..., 165, 135, 155],
#          [147, 203, 179, ..., 154, 145, 156],
#          [129, 202, 153, ..., 154, 154, 169]],
#
#         [[136, 184, 145, ..., 168, 150, 142],
#          [144, 115, 191, ..., 156, 153, 154],
#          [148, 166, 240, ..., 142, 150, 158],
#          ...,
#          [177, 185, 122, ..., 138, 148, 157],
#          [169, 156, 140, ..., 155, 155, 146],
#          [162, 201, 103, ..., 170, 159, 156]],
#
#         ...,
#
#         [[154, 154, 154, ..., 162, 140, 153],
#          [154, 154, 154, ..., 160, 151, 154],
#          [154, 154, 154, ..., 153, 159, 151],
#          ...,
#          [154, 154, 154, ..., 158, 151, 163],
#          [154, 154, 154, ..., 156, 159, 150],
#          [154, 154, 154, ..., 154, 146, 153]],
#
#         [[154, 154, 154, ..., 159, 148, 145],
#          [154, 154, 154, ..., 147, 151, 159],
#          [154, 154, 154, ..., 133, 162, 157],
#          ...,
#          [154, 154, 154, ..., 154, 150, 155],
#          [154, 154, 154, ..., 153, 156, 156],
#          [154, 154, 155, ..., 159, 177, 143]],
#
#         [[154, 154, 154, ..., 153, 153, 156],
#          [154, 154, 154, ..., 149, 153, 144],
#          [154, 154, 154, ..., 154, 154, 154],
#          ...,
#          [154, 154, 154, ..., 157, 154, 158],
#          [154, 154, 154, ..., 159, 153, 154],
#          [154, 154, 154, ..., 154, 156, 155]]], dtype=uint8),
#  array([[[  4, 177, 166, ..., 162, 160, 160],
#          [  1, 159, 161, ..., 161, 161, 158],
#          [  3, 140, 153, ..., 158, 161, 163],
#          ...,
#          [  1, 180, 159, ..., 163, 162, 165],
#          [  1, 147, 166, ..., 163, 160, 160],
#          [  2, 160, 167, ..., 159, 158, 159]],
#
#         [[155, 106, 143, ..., 161, 159, 162],
#          [171, 122, 154, ..., 157, 160, 160],
#          [181, 142, 165, ..., 157, 162, 165],
#          ...,
#          [145, 144, 173, ..., 158, 161, 160],
#          [150, 146, 169, ..., 161, 165, 162],
#          [164,  94, 149, ..., 166, 160, 163]],
#
#         [[146, 154, 214, ..., 161, 161, 161],
#          [148, 165, 222, ..., 160, 162, 162],
#          [149, 150, 234, ..., 160, 159, 162],
#          ...,
#          [169, 121, 214, ..., 159, 161, 161],
#          [177, 150, 223, ..., 162, 160, 159],
#          [177, 168, 214, ..., 161, 158, 160]],
#
#         ...,
#
#         [[161, 161, 161, ..., 161, 158, 163],
#          [161, 161, 161, ..., 162, 165, 164],
#          [161, 161, 161, ..., 161, 160, 162],
#          ...,
#          [161, 161, 161, ..., 160, 166, 160],
#          [161, 161, 161, ..., 160, 161, 160],
#          [161, 161, 161, ..., 162, 161, 162]],
#
#         [[161, 161, 161, ..., 161, 159, 163],
#          [161, 161, 161, ..., 163, 165, 163],
#          [161, 161, 161, ..., 163, 164, 162],
#          ...,
#          [161, 161, 161, ..., 161, 163, 160],
#          [161, 161, 161, ..., 162, 163, 162],
#          [161, 161, 161, ..., 161, 163, 161]],
#
#         [[161, 161, 161, ..., 162, 165, 158],
#          [161, 161, 161, ..., 162, 166, 157],
#          [161, 161, 161, ..., 159, 163, 158],
#          ...,
#          [161, 161, 161, ..., 160, 162, 163],
#          [161, 161, 161, ..., 160, 161, 160],
#          [161, 161, 161, ..., 161, 160, 161]]], dtype=uint8),
#  array([[252, 253, 252, ..., 253, 254, 254],
#         [ 48,  33,  12, ...,  48,  26,  10],
#         [ 14,  13,  13, ...,  47,  48,  43],
#         ...,
#         [ 31,  29,  30, ...,  29,  28,  30],
#         [ 29,  30,  29, ...,  31,  28,  30],
#         [ 29,  30,  29, ...,  29,  30,  29]], dtype=uint8)]

# %%
rec_img = mps_ped.to_tensor()

# %%
plt.imshow(rec_img[100, :, :].T, cmap='gray', origin='lower')

# %%
compute_ssim_2D(ped_tensor, rec_img)
# Out:
# np.float64(0.611892998692896)
